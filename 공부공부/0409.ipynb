# %%
import pandas as pd

# %%
corona=pd.read_csv("../csv/corona.csv")
corona.head(3)
# Out:
#    Unnamed: 0                 createDt  deathCnt  decideCnt  seq   stateDt  \
# 0           0  2022-06-08 09:09:05.982     24305   18188200  904  20220608
# 1           1  2022-06-07 09:09:00.897     24299   18174842  903  20220607
# 2           2  2022-06-06 09:00:06.734     24279   18168670  902  20220606
#
#   stateTime                 updateDt  accExamCnt  accDefRate
# 0     00:00                      NaN         NaN         NaN
# 1     00:00  2022-06-08 09:10:36.846         NaN         NaN
# 2     00:00  2022-06-08 09:10:50.441         NaN         NaN

# %%
corona=corona.drop("Unnamed: 0",axis=1)

# %%
corona.columns =["등록일시","누적사망자","누적확진자","게시글번호","기준일","기준시간","수정일시","누적의심자","누적확진률"]

# %%
corona.head(1)
# Out:
#                       등록일시  누적사망자     누적확진자  게시글번호       기준일   기준시간 수정일시  \
# 0  2022-06-08 09:09:05.982  24305  18188200    904  20220608  00:00  NaN
#
#    누적의심자  누적확진률
# 0    NaN    NaN

# %%
corona.sort_values("등록일시",ascending=True,inplace=True)

# %%
corona.set_index("등록일시")
# Out:
#                          누적사망자     누적확진자  게시글번호       기준일   기준시간  \
# 등록일시
# 2020-03-10 00:00:00.000     54      7513     51  20200310  00:00
# 2020-03-11 00:00:00.000     60      7755     52  20200311  00:00
# 2020-03-12 00:00:00.000     66      7869     53  20200312  00:00
# 2020-03-13 00:00:00.000     67      7979     54  20200313  00:00
# 2020-03-14 00:00:00.000     72      8086     55  20200314  00:00
# ...                        ...       ...    ...       ...    ...
# 2022-06-04 08:56:49.219  24238  18153814    900  20220604  00:00
# 2022-06-05 08:53:19.426  24258  18163648    901  20220605  00:00
# 2022-06-06 09:00:06.734  24279  18168670    902  20220606  00:00
# 2022-06-07 09:09:00.897  24299  18174842    903  20220607  00:00
# 2022-06-08 09:09:05.982  24305  18188200    904  20220608  00:00
#
#                                             수정일시     누적의심자     누적확진률
# 등록일시
# 2020-03-10 00:00:00.000   2021-10-07 10:30:51.51  210144.0  3.919308
# ...

# %%
corona.head(2)
# Out:
#                         등록일시  누적사망자  누적확진자  게시글번호       기준일   기준시간  \
# 819  2020-03-10 00:00:00.000     54   7513     51  20200310  00:00
# 818  2020-03-11 00:00:00.000     60   7755     52  20200311  00:00
#
#                        수정일시     누적의심자     누적확진률
# 819  2021-10-07 10:30:51.51  210144.0  3.919308
# 818  2021-10-07 10:30:51.51  222395.0  3.804175

# %%
corona=corona.reset_index().drop('index',axis=1)

# %%
corona.head(3)
# Out:
#                       등록일시  누적사망자  누적확진자  게시글번호       기준일   기준시간  \
# 0  2020-03-10 00:00:00.000     54   7513     51  20200310  00:00
# 1  2020-03-11 00:00:00.000     60   7755     52  20200311  00:00
# 2  2020-03-12 00:00:00.000     66   7869     53  20200312  00:00
#
#                      수정일시     누적의심자     누적확진률
# 0  2021-10-07 10:30:51.51  210144.0  3.919308
# 1  2021-10-07 10:30:51.51  222395.0  3.804175
# 2  2021-10-07 10:30:51.51  234998.0  3.621744

# %%
#corona[corona['수정일시']=="2021-10-07 10:30:51.51"]["누적사망자"].unique()

# %% [markdown]
# ###  연습문제
# 1. csv 폴더에 있는 Sales Record.csv 파일 로드
# 2. 'Order ID','Total Revenue', 'Total Cost', 'Total Profit','Sales Channel' 컬럼을 삭제
# 3. 컬럼의 이름을 변경 ->['권역','국가','상품종류','우선순위','주문일자','방송일자','판매단위','단가','원가']
# 4. 권역과 국가를 기준으로 오름차순 정렬
# 5. index 로기화하고 기존의 인덱스는 삭제

# %%
Sales=pd.read_csv("../csv/Sales Records.csv")

# %%
Sales.drop(['Order ID','Total Revenue', 'Total Cost', 'Total Profit','Sales Channel'],axis=1,inplace=True)

# %%
Sales.columns=['권역','국가','상품종류','우선순위','주문일자','방송일자','판매단위','단가','원가']
Sales.head(2)
# Out:
#                    권역      국가             상품종류 우선순위        주문일자       방송일자  \
# 0  Sub-Saharan Africa    Chad  Office Supplies    L   1/27/2011  2/12/2011
# 1              Europe  Latvia        Beverages    C  12/28/2015  1/23/2016
#
#    판매단위      단가      원가
# 0  4484  651.21  524.96
# 1  1075   47.45   31.79

# %%
Sales.sort_values(['권역','국가'],inplace=True)

# %%
Sales.reset_index(drop=True,inplace=True)

# %%
Sales
# Out:
#                       권역          국가             상품종류 우선순위        주문일자  \
# 0                   Asia  Bangladesh    Personal Care    L  12/11/2016
# 1                   Asia  Bangladesh        Cosmetics    M   7/29/2010
# 2                   Asia  Bangladesh       Vegetables    C   4/28/2014
# 3                   Asia  Bangladesh           Cereal    L   6/22/2010
# 4                   Asia  Bangladesh  Office Supplies    H   3/20/2013
# ...                  ...         ...              ...  ...         ...
# 9995  Sub-Saharan Africa    Zimbabwe          Clothes    H  11/27/2013
# 9996  Sub-Saharan Africa    Zimbabwe        Baby Food    M   3/11/2013
# 9997  Sub-Saharan Africa    Zimbabwe          Clothes    H    6/9/2010
# 9998  Sub-Saharan Africa    Zimbabwe           Fruits    C  11/20/2015
# 9999  Sub-Saharan Africa    Zimbabwe           Cereal    H   2/15/2010
#
#             방송일자  판매단위      단가      원가
# 0      1/13/2017  9420   81.73   56.67
# ...

# %%
Sales['총단가']=Sales["단가"]*Sales["판매단위"]
Sales['총원가']=Sales["원가"]*Sales["판매단위"]
Sales['총이윤']=Sales["총단가"]-Sales["총원가"]

# %%
Sales['국가'].value_counts()
# Out:
# Lithuania         72
# United Kingdom    72
# Moldova           71
# Croatia           70
# Seychelles        70
#                   ..
# Slovakia          42
# Greenland         41
# Tajikistan        40
# Saint Lucia       39
# Mali              35
# Name: 국가, Length: 185, dtype: int64

# %%
Sales.loc[Sales['국가']=='South Korea']['총이윤'].sum()
# Out:
# 23893933.75

# %%
_list= Sales['국가'].unique() 
profit_list={}
for i in _list:
    total_profit = Sales.loc[Sales['국가']==i]['총이윤'].sum()
    profit_list[i]= total_profit

# %%
profit_list
# Out:
# {'Bangladesh': 28092720.770000003,
#  'Bhutan': 23833769.239999995,
#  'Brunei': 21198560.200000003,
#  'Cambodia': 23744162.89,
#  'China': 24708015.720000003,
#  'India': 24289892.460000005,
#  'Indonesia': 16010222.29,
#  'Japan': 18574894.88,
#  'Kazakhstan': 23265602.749999996,
#  'Kyrgyzstan': 22736962.389999997,
#  'Laos': 18775038.479999997,
#  'Malaysia': 16015753.2,
#  'Maldives': 22027274.19,
#  'Mongolia': 25107838.949999996,
#  'Myanmar': 18948513.110000003,
#  'Nepal': 16677397.509999998,
#  'North Korea': 22062373.05,
#  'Philippines': 24616126.67,
#  'Singapore': 14709325.91,
#  'South Korea': 23893933.75,
#  'Sri Lanka': 22393764.24,
#  'Taiwan': 30044779.98,
#  'Tajikistan': 13662027.260000002,
#  'Thailand': 20707529.619999997,
#  'Turkmenistan': 22995182.160000004,
#  'Uzbekistan': 24896258.16,
#  'Vietnam': 23415377.02,
#  'Australia': 22393836.8,
#  'East Timor': 15514056.290000001,
#  'Federated States of Micronesia': 24231292.529999997,
# ...

# %%
# 딕셔너리형은 sort,sum등등의 함수가 없다
# 그래서 Series형태로 바꾼다음에 내림 차순으로 정렬하여서 최대값을 찾는다

pd.Series(profit_list).sort_values(ascending=False)
# Out:
# Kiribati      32454798.26
# Qatar         30861356.79
# Grenada       30302769.90
# Taiwan        30044779.98
# Malawi        29329125.05
#                  ...
# Cape Verde    14383303.52
# Italy         14199991.25
# Malta         14163744.55
# Mali          13800334.90
# Tajikistan    13662027.26
# Length: 185, dtype: float64

# %%
# dictionary형 데이터를 DataFrame형태로!!!
# values, keys는 dictionary에서, dictionary의 없는 colums은 추가 지정

pd.DataFrame(profit_list.values(),index=profit_list.keys(),columns=['sum'])
# Out:
#                     sum
# Bangladesh  28092720.77
# Bhutan      23833769.24
# Brunei      21198560.20
# Cambodia    23744162.89
# China       24708015.72
# ...                 ...
# The Gambia  18318875.15
# Togo        20026536.18
# Uganda      25940655.31
# Zambia      23637453.00
# Zimbabwe    21174631.76
#
# [185 rows x 1 columns]

# %%
Sales.groupby('권역').sum()
# Out:
# C:\Users\dgh06\AppData\Local\Temp\ipykernel_37576\3039451961.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Sales.groupby('권역').sum()
#                                        판매단위         단가         원가  \
# 권역
# Asia                                7367752  394260.70  277566.90
# Australia and Oceania               3974455  213124.94  148211.40
# Central America and the Caribbean   5177603  279197.12  198051.67
# Europe                             12955373  710315.09  500281.95
# Middle East and North Africa        6466901  344338.90  243210.08
# North America                       1155272   60021.05   42343.74
# Sub-Saharan Africa                 12931203  680173.59  478400.65
#
#                                             총단가           총원가           총이윤
# 권역
# ...

# %%
group_data=Sales.groupby(['권역','국가']).sum()
group_data.head(3)
# Out:
# C:\Users\dgh06\AppData\Local\Temp\ipykernel_37576\1643538028.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_data=Sales.groupby(['권역','국가']).sum()
#                    판매단위        단가        원가          총단가          총원가  \
# 권역   국가
# Asia Bangladesh  330991  17449.10  12217.58  97386350.24  69293629.47
#      Bhutan      288595  14265.01   9666.55  71951180.79  48117411.55
#      Brunei      229699  14484.78  10270.28  75498712.32  54300152.12
#
#                          총이윤
# 권역   국가
# Asia Bangladesh  28092720.77
#      Bhutan      23833769.24
#      Brunei      21198560.20

# %%
group_data.loc['Asia','South Korea']
# Out:
# 판매단위      319921.00
# 단가         17190.51
# 원가         12337.75
# 총단가     88488084.46
# 총원가     64594150.71
# 총이윤     23893933.75
# Name: (Asia, South Korea), dtype: float64

# %%
# Sa_R에서 상품의 종류에 따라 총 이윤이 가장 높은 물건은 무엇일까?
#1. Sa_R에서 그룹화 진행 --> 그룹조건 상품종류
#2. 그룹화된 데이터에서 총 이윤이라는 컬럼의 데이터의 평균을 출력
#3. 총이윤의 평균값을 기준으로 내림차순 정렬
#4. ??????

# %%
Sales.head(2)
# Out:
#      권역          국가           상품종류 우선순위        주문일자       방송일자  판매단위      단가  \
# 0  Asia  Bangladesh  Personal Care    L  12/11/2016  1/13/2017  9420   81.73
# 1  Asia  Bangladesh      Cosmetics    M   7/29/2010  9/11/2010   577  437.20
#
#        원가       총단가        총원가        총이윤
# 0   56.67  769896.6  533831.40  236065.20
# 1  263.33  252264.4  151941.41  100322.99

# %%
Sales["총이윤평균"]= Sales["총이윤"]/Sales["판매단위"]

# %%
Sales=Sales.groupby('상품종류').sum()
# Out:
# C:\Users\dgh06\AppData\Local\Temp\ipykernel_37576\3131971170.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Sales=Sales.groupby('상품종류').sum()

# %%
Sales.sort_values("총이윤평균",ascending=False,)
# Out:
#                     판매단위         단가         원가           총단가           총원가  \
# 상품종류
# Household        4336803  584736.25  439722.50  2.898155e+09  2.179417e+09
# Cosmetics        4103290  364624.80  219617.22  1.793958e+09  1.080519e+09
# Office Supplies  4120263  545062.77  439391.52  2.683156e+09  2.162973e+09
# Baby Food        4197006  214945.76  134231.64  1.071412e+09  6.690867e+08
# Cereal           4203394  169702.50   96615.75  8.646381e+08  4.922595e+08
# Clothes          4352350   95292.16   31252.48  4.756248e+08  1.559882e+08
# Vegetables       4238098  128794.16   76017.48  6.529214e+08  3.853703e+08
# Meat             3985390  336668.22  291022.62  1.681396e+09  1.453432e+09
# Snacks           4122781  124505.28   79511.04  6.290539e+08  4.017238e+08
# Personal Care    4402827   72576.24   50322.96  3.598431e+08  2.495082e+08
# Beverages        3910436   37105.90   24859.78  1.855502e+08  1.243128e+08
# ...

# %%
Sales
# Out:
#                     판매단위         단가         원가           총단가           총원가  \
# 상품종류
# Baby Food        4197006  214945.76  134231.64  1.071412e+09  6.690867e+08
# Beverages        3910436   37105.90   24859.78  1.855502e+08  1.243128e+08
# Cereal           4203394  169702.50   96615.75  8.646381e+08  4.922595e+08
# Clothes          4352350   95292.16   31252.48  4.756248e+08  1.559882e+08
# Cosmetics        4103290  364624.80  219617.22  1.793958e+09  1.080519e+09
# Fruits           4055921    7417.35    5501.40  3.784174e+07  2.806697e+07
# Household        4336803  584736.25  439722.50  2.898155e+09  2.179417e+09
# Meat             3985390  336668.22  291022.62  1.681396e+09  1.453432e+09
# Office Supplies  4120263  545062.77  439391.52  2.683156e+09  2.162973e+09
# Personal Care    4402827   72576.24   50322.96  3.598431e+08  2.495082e+08
# Snacks           4122781  124505.28   79511.04  6.290539e+08  4.017238e+08
# ...

# %%
Sa_R = pd.read_csv("../csv/Sales Records.csv")
Sa_R.drop(['Order ID','Total Revenue', 'Total Cost', 'Total Profit','Sales Channel'],axis=1,inplace=True)
Sa_R.columns=['권역','국가','상품종류','우선순위','주문일자','방송일자','판매단위','단가','원가']
Sa_R.sort_values(["권역","국가"],inplace=True)
Sa_R.reset_index(drop=True,inplace=True)
Sa_R['총단가']= Sa_R['판매단위'] * Sa_R['단가']
Sa_R['총원가']= Sa_R['판매단위'] * Sa_R['원가']
Sa_R['총이윤']= Sa_R['총단가'] - Sa_R['총원가']
group_data =Sa_R.groupby(['권역','국가']).sum()
Sa_R['총이윤 평균']= Sa_R['총이윤']/ Sa_R['판매단위']
Sa_R.sort_values('총이윤 평균' ,ascending=False, inplace=True)
Sa_R
# Out:
# C:\Users\dgh06\AppData\Local\Temp\ipykernel_37576\570759848.py:9: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   group_data =Sa_R.groupby(['권역','국가']).sum()
#                                      권역          국가       상품종류 우선순위  \
# 6227       Middle East and North Africa        Iran  Cosmetics    L
# 4797                             Europe   Macedonia  Cosmetics    M
# 1363                               Asia  Uzbekistan  Cosmetics    H
# 9718                 Sub-Saharan Africa    Tanzania  Cosmetics    L
# 6813       Middle East and North Africa       Qatar  Cosmetics    H
# ...                                 ...         ...        ...  ...
# 6987       Middle East and North Africa    Tunisia      Fruits    C
# 2945  Central America and the Caribbean     Jamaica     Fruits    L
# ...

# %%
NN=Sa_R.groupby("상품종류").mean()[['총이윤']].sort_values('총이윤',ascending=False)
NN.index[0]
# Out:
# C:\Users\dgh06\AppData\Local\Temp\ipykernel_37576\3675280293.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   NN=Sa_R.groupby("상품종류").mean()[['총이윤']].sort_values('총이윤',ascending=False)
# 'Cosmetics'

# %% [markdown]
# ## 예제
# 1. csv 폴더에서 4개의 파일을 로드(tran1.tran2.tran_d_1,trand_d_2)
# 2. tran_1과 tran_2는 단순한 행 추가 결합(유니언 결합)
# 3. tran_d_1, tran_d_2도 유니언 결합
# 4. 2번,3번 과정에서 나온 데이터프레임을 특정 조건에 맞춰서 2번 데이터프레임 기준으로 열 추가 결합(조인 결합)
# 5. csv폴더에 있는 2개의 파일 로드(custom_master, item_master)
# 6. 4번 과정에서 나온 데이터프레임과 custom_master 조인 결합
# 7. 6번 과정에서 나온 데이터프레임과 item_mater 조인 결합
# 8. 결합이 된 데이터프레임에서 quantity컬럼과 item_price컬럼의 데이터를 가지고 total_price라는 파생변수를 생성(total_price=item_price*quantity)

# %%
train1=pd.read_csv("../csv/tran_1.csv")
train2=pd.read_csv("../csv/tran_2.csv")
traind1=pd.read_csv("../csv/tran_d_1.csv")
traind2=pd.read_csv("../csv/tran_d_2.csv")

# %%
_train12=pd.concat([train1,train2],axis=0)
_train12.columns
# Out:
# Index(['transaction_id', 'price', 'payment_date', 'customer_id'], dtype='object')

# %%
_traind12=pd.concat([traind1,traind2],axis=0)
_traind12.columns
# Out:
# Index(['detail_id', 'transaction_id', 'item_id', 'quantity'], dtype='object')

# %%
new_train=pd.merge(_train12,_traind12,on='transaction_id',how='left')
new_train.columns
# Out:
# Index(['transaction_id', 'price', 'payment_date', 'customer_id', 'detail_id',
#        'item_id', 'quantity'],
#       dtype='object')

# %%
customer=pd.read_csv("../csv/customer_master.csv")
item=pd.read_csv("../csv/item_master.csv")
item.columns
# Out:
# Index(['item_id', 'item_name', 'item_price'], dtype='object')

# %%
new_train2=pd.merge(new_train,customer,on='customer_id',how='inner')
new_train2.columns
# Out:
# Index(['transaction_id', 'price', 'payment_date', 'customer_id', 'detail_id',
#        'item_id', 'quantity', 'name', 'class', 'gender', 'start_date',
#        'end_date', 'campaign_id', 'is_deleted'],
#       dtype='object')

# %%
new_train3=pd.merge(new_train2,item,on='item_id',how='inner')

# %%
new_train3['total_price']=new_train3['quantity']*new_train3['item_price']

# %%
new_train3
# Out:
#      transaction_id   price         payment_date customer_id  detail_id  \
# 0       T0000000113  210000  2019-02-01 01:36:57    PL563502          0
# 1       T0000003439  420000  2019-04-30 02:39:00    HD298120       3494
# 2       T0000003439  420000  2019-04-30 02:39:00    HD298120       3495
# 3       T0000000116  210000  2019-02-01 02:47:23    IK452215          3
# 4       T0000000832  210000  2019-02-19 19:48:24    IK452215        753
# ...             ...     ...                  ...         ...        ...
# 6064    T0000006675  120000  2019-07-26 04:57:13    GD139734       6910
# 6065    T0000006751  120000  2019-07-28 10:14:39    PL988722       6989
# 6066    T0000006757  120000  2019-07-28 11:23:32    HI015767       6995
# 6067    T0000006835  240000  2019-07-30 11:08:09    HI555356       7078
# 6068    T0000006890  120000  2019-07-31 20:25:02    AS554975       7135
#
#      item_id  quantity   name class gender           start_date  \
# ...

# %%
new_train3["payment_date"]=pd.to_datetime(new_train3["payment_date"])

# %%
#item_name을 total_price의 합을 그룹화 해라

#(new_train3.groupby("item_name").sum())[["total_price"]]
new_train3=new_train3[["item_name","total_price"]].groupby('item_name').sum()

# %%
new_train3.sort_values("item_name",ascending=False).index[0]
# Out:
# 'PC-E'

# %%
origin_data=new_train3.copy

# %%
origin_data()
# Out:
#            total_price
# item_name
# PC-A         128900000
# PC-B         129030000
# PC-C         105720000
# PC-D         136260000
# PC-E         326130000

# %%
# apply() 사용하여 남자,여자 변경

def change(x):
    if x=='M':
        result='남자'
    elif x=='F':
        result='여자'
    return result

new_train3['gender']=new_train3['gender'].apply(change)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\dgh06\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\dgh06\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\dgh06\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gender'
#
# ...

# %%
new_train3["payment_month"]=new_train3['payment_date'].dt.strftime("%m-%Y")

# %%
new_train3

# %%
# 월별 거래량을 확인
new_train3.groupby("payment_month").sum()[["total_price"]]
new_train3.groupby("payment_month").agg(['mean','sum'])["total_price"]
# Out:
# C:\Users\dgh06\AppData\Local\Temp\ipykernel_37576\299089415.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   new_train3.groupby("payment_month").sum()[["total_price"]]
# C:\Users\dgh06\AppData\Local\Temp\ipykernel_37576\299089415.py:3: FutureWarning: ['transaction_id', 'payment_date', 'customer_id', 'item_id', 'name', 'class', 'gender', 'start_date', 'end_date', 'campaign_id', 'item_name'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   new_train3.groupby("payment_month").agg(['mean','sum'])["total_price"]
#                         mean        sum
# payment_month
# 02-2019        137592.964824  136905000
# 03-2019        135154.382470  135695000
# 04-2019        136106.106106  135970000
# ...

# %% [markdown]
# ## 예제
# 1. drinks.csv 파일 로드
# 2. 결측치 확인
# 3. 데이터프레임의 정보 출력
# 4. continent 칼럼에서 결측치 존채 -> 결측치 'OT'로 대체
# 5. continent 별 spirit_servings 칼럼의 평균,최소 ,최대, 합계를 출력
# 6. total_litres_of_pure_alcohol 칼럼의 평균보다 높은 continent가 어디인지 출력
# 7. 국가별 술 소비량 대비 알콜의 비율 컬럼을 추가

# %%
drinks=pd.read_csv("../csv/drinks.csv")
drinks.isna().sum()
# Out:
# country                          0
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       23
# dtype: int64

# %%
drinks.fillna('OT',inplace=True)
drinks.isna().sum()
drinks.head(3)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF

# %%
group_data=drinks.groupby("continent").agg(["mean","min","max","sum"])
group_data.head(3)
# Out:
# C:\Users\dgh06\AppData\Local\Temp\ipykernel_37576\3965866364.py:1: FutureWarning: ['country'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   group_data=drinks.groupby("continent").agg(["mean","min","max","sum"])
#           beer_servings                spirit_servings                 \
#                    mean min  max   sum            mean min  max   sum
# continent
# AF            61.471698   0  376  3258       16.339623   0  152   866
# AS            37.045455   0  247  1630       60.840909   0  326  2677
# EU           193.777778   0  361  8720      132.555556   0  373  5965
#
#           wine_servings                total_litres_of_pure_alcohol       \
#                    mean min  max   sum                         mean  min
# continent
# AF            16.264151   0  233   862                     3.007547  0.0
# ...

# %%
group_data["total_litres_of_pure_alcohol"]
# Out:
#                mean  min   max    sum
# continent
# AF         3.007547  0.0   9.1  159.4
# AS         2.170455  0.0  11.5   95.5
# EU         8.617778  0.0  14.4  387.8
# OC         3.381250  0.0  10.4   54.1
# OT         5.995652  2.2  11.9  137.9
# SA         6.308333  3.8   8.3   75.7

# %%
ND=drinks["total_litres_of_pure_alcohol"].mean()

# %%
group_date2=group_data["total_litres_of_pure_alcohol"]['mean']

# %%
group_date2[group_date2>ND].index
# Out:
# Index(['EU', 'OT', 'SA'], dtype='object', name='continent')

# %%
# 7.국가별 술 소비량 대비 알콜 비율 컬럼을 추가


# 국가별 술 소비량 파생변수 생성
drinks["total_servings"]=drinks['beer_servings'] + drinks["spirit_servings"] +drinks["wine_servings"]

# %%
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent  total_servings
# 0                             0.0        AS               0
# 1                             4.9        EU             275
# ...

# %%
# 술 소비량 대비 알콜 비율이라는 파생 변수 생성
# (알콜 소비량 / 술 소비량) *100
# 결측치가 나온다면 0으로 대체해준다
drinks["alcohol_rate"]=(drinks["total_litres_of_pure_alcohol"]/ drinks["total_servings"] * 100).fillna(0)

# %%
# 가장 독한 술을 먹는 나라는 어디인가?
# 우리나라는 얼마나 독한 술을 마시는가?
# 북한은 얼마나 독한 술을 먹는가?

drinks_rank=drinks.sort_values("alcohol_rate",ascending=False,ignore_index=True)
drinks_rank
# Out:
#           country  beer_servings  spirit_servings  wine_servings  \
# 0          Gambia              8                0              1
# 1    Sierra Leone             25                3              2
# 2         Nigeria             42                5              2
# 3          Uganda             45                9              0
# 4          Rwanda             43                2              0
# ..            ...            ...              ...            ...
# 188      Maldives              0                0              0
# 189         Libya              0                0              0
# 190          Iran              0                0              0
# 191        Kuwait              0                0              0
# 192   Afghanistan              0                0              0
#
#      total_litres_of_pure_alcohol continent  total_servings  alcohol_rate
# 0                             2.4        AF               9     26.666667
# ...

# %%
drinks_rank.loc[drinks_rank["country"]=="South Korea","country"]
# Out:
# 14    South Korea
# Name: country, dtype: object

# %% [markdown]
# ## 예제
# 1. test_csv폴더에 있는 '유통+업종(백화점,+할인점,+슈퍼마켓,+편의점)+카드소비트렌드+데이터_1901_2109'파일을 로드
# 2. 각 컬럼의 이름을['기준연월','업종','성별',연령대','총이용건수','총이용금액']
# 3. 기준년월을 시계열데이터로 변경
# 4. 성별 컬럼의 데이터를 1은 남자,2는 여자로 변경,9는 무관
# 5. 남,녀 성별을 기준으로 연도별 전당 이용금액의 평균이 몇인지 출력

# %%
_group1=pd.read_csv("../test_csv/유통+업종(백화점,+할인점,+슈퍼마켓,+편의점)+카드소비트렌드+데이터_1901_2109.csv", encoding='euc-kr')
_group1.head(1)
# Out:
#      crym tco_btc_nm  ma_fem_dc  agegrp_dc  tco_btc_u_ct  tco_btc_u_am
# 0  201901        백화점          1          1             1        7600.0

# %%
_group1.columns=['기준연월','업종','성별','연령대','총이용건수','총이용금액']
_group1.head(1)
# Out:
#      기준연월   업종  성별  연령대  총이용건수   총이용금액
# 0  201901  백화점   1    1      1  7600.0

# %%
_group1["기준연월"]=pd.to_datetime(_group1["기준연월"],format="%Y%m")
_group1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2648 entries, 0 to 2647
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   기준연월    2648 non-null   datetime64[ns]
#  1   업종      2648 non-null   object
#  2   성별      2648 non-null   int64
#  3   연령대     2648 non-null   int64
#  4   총이용건수   2648 non-null   int64
#  5   총이용금액   2648 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1)
# memory usage: 124.3+ KB

# %%
_group1.set_index("기준연월",inplace=True)

# %%
def change(x):
    if x==1:
        result ='남자'
    elif x==2:
        result = '여자'
    elif x==9:
        result = '성별무관'
    else:
        result='-'
    return result

#_group1["성별"].apply(change).value_counts()
_group1["성별"]=_group1["성별"].apply(change)
#_group1["성별"].apply(change).value_counts()

# %%
#5. 남,녀 성별을 기준으로 연도별 건당 이용금액의 평균이 몇인지 출력
_group1.head(3)
# Out:
#              업종  성별  연령대  총이용건수         총이용금액
# 기준연월
# 2019-01-01  백화점  남자    1      1  7.600000e+03
# 2019-01-01  백화점  남자   10    379  1.945872e+07
# 2019-01-01  백화점  남자   20  45173  4.747711e+09

# %%
_group1["건당이용금액"]=_group1["총이용금액"]/_group1["총이용건수"]
_group1["연도"]=_group1.index.strftime("%Y")
_group1["연도"]=_group1.index.strftime("%Y")

# %%
_group1.head(3)
# Out:
#              업종  성별  연령대  총이용건수         총이용금액         건당이용금액    연도
# 기준연월
# 2019-01-01  백화점  남자    1      1  7.600000e+03    7600.000000  2019
# 2019-01-01  백화점  남자   10    379  1.945872e+07   51342.269129  2019
# 2019-01-01  백화점  남자   20  45173  4.747711e+09  105100.635357  2019

# %%
_group1.groupby(["성별","연도"]).mean()["건당이용금액"]
# Out:
# C:\Users\dgh06\AppData\Local\Temp\ipykernel_37576\2842004448.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   _group1.groupby(["성별","연도"]).mean()["건당이용금액"]
# 성별  연도
# 남자  2019    39184.349662
#     2020    44009.589591
#     2021    46948.320084
# 여자  2019    38107.838544
#     2020    41389.763130
#     2021    43306.318972
# Name: 건당이용금액, dtype: float64

# %% [markdown]
# ### 온라인 카드 매출과 오프라인 카드 매출을 월별로 비교
# 1. 오프라인 데이터 _group1을 월별로 그룹화 총이용금액의 합계
#     - 인덱스는 시준연월을 시계열로 변경한 데이터로 설정
# 2. 온라인 데이터를 _group2_도 월별로 그룹화 총이용금액의 합계
#     - 인덱스는 기준연월을 시계열로 변경한 데이터로 설정

# %%
_group1.head(3)
# Out:
#              업종  성별  연령대  총이용건수         총이용금액         건당이용금액    연도
# 기준연월
# 2019-01-01  백화점  남자    1      1  7.600000e+03    7600.000000  2019
# 2019-01-01  백화점  남자   10    379  1.945872e+07   51342.269129  2019
# 2019-01-01  백화점  남자   20  45173  4.747711e+09  105100.635357  2019

# %%
_group_data1=_group1.groupby(_group1.index).sum()["총이용금액"]
# Out:
# C:\Users\dgh06\AppData\Local\Temp\ipykernel_37576\2887468851.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   _group_data1=_group1.groupby(_group1.index).sum()["총이용금액"]

# %%
_group2=pd.read_csv("../test_csv/온라인+카드소비트렌드+데이터_1901_2109.csv")
_group2.columns =['기준연월','성별','연령대','총이용건수','총이용금액']
_group2["기준연월"]=pd.to_datetime(_group2['기준연월'],format='%Y%m')
_group2.set_index('기준연월', inplace=True)
group_data2=_group2.groupby('기준연월').sum()['총이용금액']
group_data2.head()
# Out:
# 기준연월
# 2019-01-01    778281658966
# 2019-02-01    669627559900
# 2019-03-01    769982635445
# 2019-04-01    769343707461
# 2019-05-01    785876486705
# Name: 총이용금액, dtype: int64

# %%
import platform
import matplotlib.pyplot as plt

# %%
# 그래프로 시각화

#그래프 사이즈 변경
plt.figure(figsize=(14,6))

#grid 추가
plt.grid(True, axis='y')

#지수표현 제거
plt.ticklabel_format(axis = 'y',style='plain')

plt.plot(_group_data1,label='오프라인')
plt.plot(group_data2, label='온라인')
plt.title('온라인/오프라인 카드매출 비교')
plt.legend()
plt.show()
# Out:
# C:\Users\dgh06\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dgh06\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46972 (\N{HANGUL SYLLABLE RA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dgh06\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\dgh06\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50724 (\N{HANGUL SYLLABLE O}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
total_df=pd.concat([_group1,_group2],axis=0)

# %%
total_df['업종'].value_counts()
# Out:
# 편의점     667
# 백화점     664
# 슈퍼마켓    663
# 할인점     654
# Name: 업종, dtype: int64

# %%
total_df
# Out:
#              업종  성별  연령대    총이용건수         총이용금액         건당이용금액    연도
# 기준연월
# 2019-01-01  백화점  남자    1        1  7.600000e+03    7600.000000  2019
# 2019-01-01  백화점  남자   10      379  1.945872e+07   51342.269129  2019
# 2019-01-01  백화점  남자   20    45173  4.747711e+09  105100.635357  2019
# 2019-01-01  백화점  남자   30   271858  2.791826e+10  102694.279892  2019
# 2019-01-01  백화점  남자   40   391109  3.791149e+10   96933.301601  2019
# ...         ...  ..  ...      ...           ...            ...   ...
# 2021-09-01  NaN   2   50  3237324  1.813605e+11            NaN   NaN
# 2021-09-01  NaN   2   60  1019719  7.002663e+10            NaN   NaN
# 2021-09-01  NaN   2   70   159261  1.309103e+10            NaN   NaN
# 2021-09-01  NaN   2   80    20094  1.935122e+09            NaN   NaN
# 2021-09-01  NaN   2   90      611  5.284020e+07            NaN   NaN
#
# [3299 rows x 7 columns]
