# %% [markdown]
# # mysql과 python 연동
# 1. 라이브러리 설치
# 2. sql 서버의 정보를 등록
# 3. sql 서버에 접속
# 4. sql 쿼리문을 이용하여 데이터를 CRUD작업

# %%
# pymysql 설치
# pip install pymysql

# %%
import pymysql

# %%
# Sql 서버의 종류 입력
_db =pymysql.connect(
    user ="root",
    password='1234',
    host='localhost',
    db='ubion7',
    port=3306

)

# %%
# cursor 변수 생성
# sql 퀴리문을 실행 시키기 위한 필수 변수
# Dictcursor는 sql 쿼리문이 실행되고 나온 데이터를 딕셔너리 형태로 받는다.

cursor= _db.cursor(pymysql.cursors.DictCursor)

# %%
print(cursor)
# Out:
# <pymysql.cursors.DictCursor object at 0x00000247989CD1D0>

# %%
sql= """
    select
    *
    from
    user_info
"""

cursor.execute(sql)
# Out:
# 6

# %%
result=cursor.fetchall()

# %%
print(result)
# Out:
# [{'Name': 'A', 'Gender': 'male', 'Phone': '010-1234-5678'}, {'Name': 'B', 'Gender': 'female', 'Phone': '010-1234-5679'}, {'Name': 'C', 'Gender': 'male', 'Phone': '010-1234-5680'}, {'Name': 'D', 'Gender': 'female', 'Phone': '010-1234-5681'}, {'Name': 'E', 'Gender': 'male', 'Phone': '010-1234-5682'}, {'Name': 'F', 'Gender': 'female', 'Phone': '010-1234-5683'}, {'Name': 'G', 'Gender': 'male', 'Phone': '010-1234-5684'}, {'Name': 'H', 'Gender': 'female', 'Phone': '010-1234-5685'}, {'Name': 'I', 'Gender': 'male', 'Phone': '010-1234-5686'}, {'Name': 'J', 'Gender': 'female', 'Phone': '010-1234-5687'}]

# %%
import pandas as pd

# %%
pd.DataFrame(result)
# Out:
#   user_id user_pass user_name   user_phone  user_gender
# 0    test      1234      test  01012345678            1
# 1   test2      1234     test2  01011111111            2
# 2   test3      1234     test3  01099999999            1
# 3   test4      1111     test4  01011111111            1
# 4   test5      1234     test5  01011118888            1
# 5   test6      1274     test6  01011119999            1

# %%
sql="""
    select
    *
    from
    example
"""

cursor.execute(sql)
result=cursor.fetchall()
df=pd.DataFrame(result)
df
# Out:
#   Name  Gender          Phone
# 0    A    male  010-1234-5678
# 1    B  female  010-1234-5679
# 2    C    male  010-1234-5680
# 3    D  female  010-1234-5681
# 4    E    male  010-1234-5682
# 5    F  female  010-1234-5683
# 6    G    male  010-1234-5684
# 7    H  female  010-1234-5685
# 8    I    male  010-1234-5686
# 9    J  female  010-1234-5687

# %%
sql="""
    insert into
    user_info
    values
    ("test6","1274","test6","01011119999",1)
"""

cursor.execute(sql)      #깃허브 commit
# Out:
# 1

# %%
_db.commit()             #깃허브 push

# %% [markdown]
# ### sql 함수화
# 1. 첫 번째 함수
#     - 매개변수 1개(sql 쿼리문)
#     - sql  쿼리문을 실행하고 결과를 데이터프레임으로 변경하여 return
# 2. 두 번째 함수
#     - 매개변수 1개(sql 쿼리문)
#     - sql 쿼리문을 실행하고 데이터베이스를 변경
# 3. 세 번째 함수
#     - 1번 함수와 2번 함수를 하나의 함수에서 실행이 될 수 있다고록 생성

# %%
def _first(sql):
    # 쿼리문 실행
    cursor.execute(sql)
    # 쿼리문에 대한 결과
    result=cursor.fetchall()
    return pd.DataFrame(result)

# %%
def _second(sql,values):
    cursor.execute(sql,values)
    _db.commit()

# %%
_sql=("""
    insert into
    user_info
    values
    (%s,%s,%s,%s,%s)
""")
values=['test11','12234','test10','01077777777',1]

_second(_sql,values)

# %%
def sql_query(sql,values=[]):
    
    #if (sql.find("select") != -1) and (sql.find('select')<10):
    
    if (sql.replace('\n','').strip().startswith('select')):
        cursor.execute(sql,values)
        result=cursor.fetchall()
        result=pd.DataFrame(result)
    else:
        cursor.execute(sql,values)
        _db.commit()
        result ="Query Ok"
        
    return result

# %%
sql='''
    select
    *
    from
    user_info
'''
sql_query(sql)
# Out:
#   user_id user_pass user_name   user_phone  user_gender
# 0    test      1234      test  01012345678            1
# 1   test2      1234     test2  01011111111            2
# 2   test3      1234     test3  01099999999            1
# 3   test4      1111     test4  01011111111            1
# 4   test5      1234     test5  01011118888            1
# 5   test6      1274     test6  01011119999            1
# 6   test7      1274     test6  01011119999            1

# %%
_sql=("""
    delete
    from
    user_info
    where
    user_id =%s
    
""")
# where in (%s,%s,%s)
values=['test11']

sql_query(_sql,values)
# Out:
# 'Query Ok'

# %%
import mod_sql
import imp
imp.reload(mod_sql)
# Out:
# C:\Users\dgh06\AppData\Local\Temp\ipykernel_26920\2748340258.py:2: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp
# <module 'mod_sql' from 'c:\\Users\\dgh06\\OneDrive\\문서\\GitHub\\python-work\\230417\\mod_sql\\__init__.py'>

# %%
test=mod_sql.Database(_host='localhost',_user='root',_pass='1234',_db='ubion7',_port=3306)

# %%
a='''
    select
    *
    from
    user_info
'''
test.sql_query(a)
# Out:
#   user_id user_pass user_name   user_phone  user_gender
# 0    test      1234      test  01012345678            1
# 1   test2      1234     test2  01011111111            2
# 2   test3      1234     test3  01099999999            1
# 3   test4      1111     test4  01011111111            1
# 4   test5      1234     test5  01011118888            1
# 5   test6      1274     test6  01011119999            1
# 6   test7      1274     test6  01011119999            1

# %%
import mod_sql
imp.reload(mod_sql)
# Out:
# <module 'mod_sql' from 'c:\\Users\\dgh06\\OneDrive\\문서\\GitHub\\python-work\\230417\\mod_sql\\__init__.py'>

# %%
test2=mod_sql.Database(
    '172.16.11.148',
    'ubion',
    '1234',
    'ubion7',
    3306
)
_sql=("""
    insert into
    user_info
    values
    (%s,%s,%s,%s,%s)
""")
values=['test99','1465','test99','01077777777',1]

test2.sql_query(_sql,values)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Cell In[123], line 16
#       8 _sql=("""
#       9     insert into
#      10     user_info
#      11     values
#      12     (%s,%s,%s,%s,%s)
#      13 """)
#      14 values=['test99','1465','test99','01077777777',1]
# ---> 16 test2.sql_query(_sql,values)
#
# File c:\Users\dgh06\OneDrive\문서\GitHub\python-work\230417\mod_sql\__init__.py:24, in Database.sql_query(self, sql, values)
#      22     result=pd.DataFrame(result)
#      23 else:
# ---> 24     self.cursor.execute(sql,values)
#      25     self.db.commit()
#      26     result ="Query Ok"
#
# File c:\Users\dgh06\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\cursors.py:158, in Cursor.execute(self, query, args)
#     154     pass
#     156 query = self.mogrify(query, args)
# --> 158 result = self._query(query)
#     159 self._executed = query
#     160 return result
#
# File c:\Users\dgh06\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\cursors.py:325, in Cursor._query(self, q)
#     323 conn = self._get_db()
#     324 self._clear_result()
# --> 325 conn.query(q)
#     326 self._do_get_result()
#     327 return self.rowcount
#
# File c:\Users\dgh06\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:549, in Connection.query(self, sql, unbuffered)
#     547     sql = sql.encode(self.encoding, "surrogateescape")
#     548 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 549 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     550 return self._affected_rows
#
# File c:\Users\dgh06\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:779, in Connection._read_query_result(self, unbuffered)
#     777 else:
#     778     result = MySQLResult(self)
# --> 779     result.read()
#     780 self._result = result
#     781 if result.server_status is not None:
#
# File c:\Users\dgh06\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:1157, in MySQLResult.read(self)
#    1155 def read(self):
#    1156     try:
# -> 1157         first_packet = self.connection._read_packet()
#    1159         if first_packet.is_ok_packet():
#    1160             self._read_ok_packet(first_packet)
#
# File c:\Users\dgh06\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\connections.py:729, in Connection._read_packet(self, packet_type)
#     727     if self._result is not None and self._result.unbuffered_active is True:
#     728         self._result.unbuffered_active = False
# --> 729     packet.raise_for_error()
#     730 return packet
#
# File c:\Users\dgh06\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File c:\Users\dgh06\AppData\Local\Programs\Python\Python311\Lib\site-packages\pymysql\err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# IntegrityError: (1062, "Duplicate entry 'test99' for key 'user_info.PRIMARY'")

# %%
a='''
    select
    *
    from
    user_info
'''
test2.sql_query(a)
# Out:
#   user_id user_pass  user_name   user_phone  user_gender
# 0  hungry      8282  youngsang  01013131313            2
# 1   sejin      0617      sejin  01088218821            2
# 2  test99      1465     test99  01077777777            1

# %%
sql='''
    select
    `Name` as '이름',
    `Phone` as '휴대폰번호'
    from
    example
    where
    `Gender` = %s
    limit 3
'''
values=['male']
test.sql_query(sql,values)

# limit 3 : 3개만 뽑겠다
# 콜럼의 이름에 ``붙이는게 좋다-->띄어쓰기 방지!-->앞에 하나의 단어만 인식함
# Out:
#   이름          휴대폰번호
# 0  A  010-1234-5678
# 1  C  010-1234-5680
# 2  E  010-1234-5682

# %%
sql='''
    select
    createDt as '등록일시',
    deathCnt as '사망자',
    decideCnt as '감염자'
    from
    corona

'''
test.sql_query(sql)
# Out:
#                         등록일시    사망자       감염자
# 0    2022-06-08 09:09:05.982  24305  18188200
# 1    2022-06-07 09:09:00.897  24299  18174842
# 2    2022-06-06 09:00:06.734  24279  18168670
# 3    2022-06-05 08:53:19.426  24258  18163648
# 4    2022-06-04 08:56:49.219  24238  18153814
# ..                       ...    ...       ...
# 815  2020-03-14 00:00:00.000     72      8086
# 816  2020-03-13 00:00:00.000     67      7979
# 817  2020-03-12 00:00:00.000     66      7869
# 818  2020-03-11 00:00:00.000     60      7755
# 819  2020-03-10 00:00:00.000     54      7513
#
# [820 rows x 3 columns]

# %%
test2.sql_close()

# %%
df=pd.read_csv('../csv/corona.csv',index_col=False)
df=df[["createDt","deathCnt","decideCnt"]]
df.columns=['등록일시','사망자','감염자']
df
# Out:
#                         등록일시    사망자       감염자
# 0    2022-06-08 09:09:05.982  24305  18188200
# 1    2022-06-07 09:09:00.897  24299  18174842
# 2    2022-06-06 09:00:06.734  24279  18168670
# 3    2022-06-05 08:53:19.426  24258  18163648
# 4    2022-06-04 08:56:49.219  24238  18153814
# ..                       ...    ...       ...
# 815  2020-03-14 00:00:00.000     72      8086
# 816  2020-03-13 00:00:00.000     67      7979
# 817  2020-03-12 00:00:00.000     66      7869
# 818  2020-03-11 00:00:00.000     60      7755
# 819  2020-03-10 00:00:00.000     54      7513
#
# [820 rows x 3 columns]

# %%
sql="""
    select
    `Country` as '국가',
    `Units Sold` as '판매개수',
    `Unit Price` as `가격`,
    `Unit Cost` as `원가`,
    (`Units Sold` * `Unit Price`) as `총수익`,
    (`Units Sold` * `Unit Cost`) as '총비용',
    ((`Units Sold` * `Unit Price`) - (`Units Sold` * `Unit Cost`)) as `총이윤`
    from 
    `Sales Records`

"""
test.sql_query(sql)
# Out:
#                                     국가  판매개수      가격      원가         총수익  \
# 0                                 Chad  4484  651.21  524.96  2920025.64
# 1                               Latvia  1075   47.45   31.79    51008.75
# 2                             Pakistan  6515  154.06   90.93  1003700.90
# 3     Democratic Republic of the Congo  7683  668.27  502.54  5134318.41
# 4                       Czech Republic  3491   47.45   31.79   165647.95
# ...                                ...   ...     ...     ...         ...
# 9995                              Laos  8597   47.45   31.79   407927.65
# 9996                     Liechtenstein   562  437.20  263.33   245706.40
# 9997  Democratic Republic of the Congo  2524  154.06   90.93   388847.44
# 9998                      South Africa  8706  421.89  364.69  3672974.34
# 9999                          Mongolia   361  152.58   97.44    55081.38
#
#              총비용         총이윤
# 0     2353920.64   566105.00
# 1       34174.25    16834.50
# 2      592408.95   411291.95
# 3     3861014.82  1273303.59
# 4      110978.89    54669.06
# ...          ...         ...
# 9995   273298.63   134629.02
# 9996   147991.46    97714.94
# 9997   229507.32   159340.12
# 9998  3174991.14   497983.20
# 9999    35175.84    19905.54
#
# [10000 rows x 7 columns]
