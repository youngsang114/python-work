# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 절대 모멘텀
# 1. 주식 데이터 로드
# 2. 파생변수 년월 패상변수 생성 -> Date 컬럼에서 년-월 추출 대입
# 3. 년,월 별 마지막날의 month_last_dt 데이터 프레임을 생성
# 4. 전월의 종가를 가지는 파생변수 하나 생성
# 5. 전년도의 종가를 가지는 파생변수 하나 생성
# 6. 전월, 전년도의 종가를 가지고 거래내역 생성
# 7. 수익율 계산

# %%
df=pd.read_csv("../csv/GDX.csv",index_col='Date')

# %%
df.index
# 인덱스를 시계열 데이터로 변경
df.index=pd.to_datetime(df.index,format="%Y-%m-%d")

# %% [markdown]
# # to_datetime 기능을 구현

# %%
# datetime 라이브러리를 이용하여 시계열로 변경

from datetime import datetime

# %%
test_df=df.copy()

# %%
#case 1
test_df=test_df.reset_index()
test_df["Date"]=test_df["Date"].apply(lambda x: datetime.strptime(x,"%Y-%m-%d"))
test_df.set_index('Date')
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2006-05-22  36.520000  37.290001  35.869999  37.230000  34.280224     197100
# 2006-05-23  37.750000  39.220001  37.750000  37.959999  34.952393     620900
# 2006-05-24  37.130001  37.570000  35.869999  36.520000  33.626480     638600
# 2006-05-25  37.180000  38.320000  36.980000  38.320000  35.283867     367000
# 2006-05-26  38.740002  38.740002  37.770000  38.549999  35.495640     269400
# ...               ...        ...        ...        ...        ...        ...
# 2019-06-18  23.750000  23.879999  23.350000  23.670000  23.670000   44411200
# 2019-06-19  23.520000  24.030001  23.450001  24.000000  24.000000   46273800
# 2019-06-20  24.660000  25.170000  24.540001  25.049999  25.049999  131981000
# 2019-06-21  25.000000  25.240000  24.680000  25.209999  25.209999   50304400
# 2019-06-24  25.309999  25.770000  25.260000  25.703501  25.703501   27806170
#
# [3295 rows x 6 columns]

# %%
# map 함수
x=[1,2,3,4]
def change(x):
    return x**2

list(map(change,x))
list(map(lambda y :y**2,x))
# lsit,tuple-->map 
# series, DF--->apply
# Out:
# [1, 4, 9, 16]

# %%
# case2
test_df.index

def change(x):
    return datetime.strptime(x, "%Y-%m-%d")

test_df.index=list(map(change,test_df.index))

# %%
test_df.head(2)
# Out:
#              Open       High        Low      Close  Adj Close  Volume
# 2006-05-22  36.52  37.290001  35.869999  37.230000  34.280224  197100
# 2006-05-23  37.75  39.220001  37.750000  37.959999  34.952393  620900

# %%
# 다시 !!!!!
# 새로운 파생변수 년-월 데이터를 대입

#df.index.dt.strftime("%Y-%m")  # dt는 판다스안에 있는 dt의 항목(데이터가 시계열인거 EX)str)
df['STD-YM']=list(map(lambda x: datetime.strftime(x,'%Y-%m'),df.index))
df
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2006-05-22  36.520000  37.290001  35.869999  37.230000  34.280224     197100
# 2006-05-23  37.750000  39.220001  37.750000  37.959999  34.952393     620900
# 2006-05-24  37.130001  37.570000  35.869999  36.520000  33.626480     638600
# 2006-05-25  37.180000  38.320000  36.980000  38.320000  35.283867     367000
# 2006-05-26  38.740002  38.740002  37.770000  38.549999  35.495640     269400
# ...               ...        ...        ...        ...        ...        ...
# 2019-06-18  23.750000  23.879999  23.350000  23.670000  23.670000   44411200
# 2019-06-19  23.520000  24.030001  23.450001  24.000000  24.000000   46273800
# 2019-06-20  24.660000  25.170000  24.540001  25.049999  25.049999  131981000
# 2019-06-21  25.000000  25.240000  24.680000  25.209999  25.209999   50304400
# 2019-06-24  25.309999  25.770000  25.260000  25.703501  25.703501   27806170
#
#              STD-YM
# Date
# ...

# %%
#case 1(shift 이용)
# 현재의 STD_YM의 값과 다음 행의 STD-YM의 값이 다른 경우
df.loc[df["STD-YM"] != df.shift(-1)["STD-YM"]]
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2006-05-31  38.900002  39.130001  38.119999  38.849998  35.771877    350700
# 2006-06-30  38.700001  39.060001  38.320000  38.700001  35.633759   1069400
# 2006-07-31  38.730000  38.860001  38.230000  38.759998  35.688999    233900
# 2006-08-31  40.290001  40.599998  40.020000  40.590000  37.374012    535200
# 2006-09-29  35.400002  36.220001  35.400002  35.650002  32.825417    342000
# ...               ...        ...        ...        ...        ...       ...
# 2019-02-28  22.360001  22.360001  22.160000  22.240000  22.240000  32776800
# 2019-03-29  22.610001  22.650000  22.389999  22.420000  22.420000  35233000
# 2019-04-30  20.830000  21.030001  20.799999  20.889999  20.889999  19674200
# 2019-05-31  21.240000  21.740000  21.190001  21.590000  21.590000  83347600
# 2019-06-24  25.309999  25.770000  25.260000  25.703501  25.703501  27806170
#
#              STD-YM
# Date
# 2006-05-31  2006-05
# ...

# %%
# case2(for문)

month_list_df= pd.DataFrame()

_list=df["STD-YM"].unique()

for i in _list:
    last_df=df.loc[df["STD-YM"] ==i].tail(1)
    month_list_df =pd.concat([month_list_df, last_df])

month_list_df.head(24)
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2006-05-31  38.900002  39.130001  38.119999  38.849998  35.771877   350700
# 2006-06-30  38.700001  39.060001  38.320000  38.700001  35.633759  1069400
# 2006-07-31  38.730000  38.860001  38.230000  38.759998  35.688999   233900
# 2006-08-31  40.290001  40.599998  40.020000  40.590000  37.374012   535200
# 2006-09-29  35.400002  36.220001  35.400002  35.650002  32.825417   342000
# 2006-10-31  37.009998  37.970001  37.000000  37.959999  34.952393   583000
# 2006-11-30  41.169998  41.980000  41.029999  41.980000  38.653877  1055700
# 2006-12-29  40.000000  40.000000  39.549999  39.910000  36.854694   548200
# 2007-01-31  38.970001  39.779999  38.959999  39.599998  36.568424   643000
# 2007-02-28  39.400002  40.119999  38.830002  39.990002  36.928577  1259900
# 2007-03-30  39.700001  39.799999  39.360001  39.570000  36.540733   399500
# ...

# %%
# 전월의 종가를 가지는 파생변수(BF_1M)을 생성하고 결측치는 0으로 대체
# 전년도의 종가를(Adj Close)를 가지는 파생변수(BF_12M)을 생성하고 결측치는 0으로 대체

# %%
month_list_df['BF_1M']=month_list_df.loc[df["STD-YM"] != df.shift(-1)["STD-YM"]]["Adj Close"].shift(1)
month_list_df['BF_12M']=month_list_df.loc[df["STD-YM"] != df.shift(-12)["STD-YM"]]["Adj Close"].shift(12)
month_list_df.fillna(0)

# month_list_df['BF_1M']=month_list_df.shift(1)['Adj Close'].fillna(0)
# month_list_df['BF_12M']=month_list_df.shift(12)['Adj Close'].fillna(0)
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2006-05-31  38.900002  39.130001  38.119999  38.849998  35.771877    350700
# 2006-06-30  38.700001  39.060001  38.320000  38.700001  35.633759   1069400
# 2006-07-31  38.730000  38.860001  38.230000  38.759998  35.688999    233900
# 2006-08-31  40.290001  40.599998  40.020000  40.590000  37.374012    535200
# 2006-09-29  35.400002  36.220001  35.400002  35.650002  32.825417    342000
# ...               ...        ...        ...        ...        ...       ...
# 2019-02-28  22.360001  22.360001  22.160000  22.240000  22.240000  32776800
# 2019-03-29  22.610001  22.650000  22.389999  22.420000  22.420000  35233000
# 2019-04-30  20.830000  21.030001  20.799999  20.889999  20.889999  19674200
# 2019-05-31  21.240000  21.740000  21.190001  21.590000  21.590000  83347600
# 2019-06-24  25.309999  25.770000  25.260000  25.703501  25.703501  27806170
#
#              STD-YM      BF_1M     BF_12M
# Date
# ...

# %%
month_list_df.fillna(0)
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2006-05-31  38.900002  39.130001  38.119999  38.849998  35.771877    350700
# 2006-06-30  38.700001  39.060001  38.320000  38.700001  35.633759   1069400
# 2006-07-31  38.730000  38.860001  38.230000  38.759998  35.688999    233900
# 2006-08-31  40.290001  40.599998  40.020000  40.590000  37.374012    535200
# 2006-09-29  35.400002  36.220001  35.400002  35.650002  32.825417    342000
# ...               ...        ...        ...        ...        ...       ...
# 2019-02-28  22.360001  22.360001  22.160000  22.240000  22.240000  32776800
# 2019-03-29  22.610001  22.650000  22.389999  22.420000  22.420000  35233000
# 2019-04-30  20.830000  21.030001  20.799999  20.889999  20.889999  19674200
# 2019-05-31  21.240000  21.740000  21.190001  21.590000  21.590000  83347600
# 2019-06-24  25.309999  25.770000  25.260000  25.703501  25.703501  27806170
#
#              STD-YM      BF_1M     BF_12M
# Date
# ...

# %%
month_list_df.iloc[[0,13]]
# Out:
#                  Open       High        Low      Close  Adj Close  Volume  \
# Date
# 2006-05-31  38.900002  39.130001  38.119999  38.849998  35.771877  350700
# 2007-06-29  37.759998  38.020000  37.619999  37.889999  34.989338  508500
#
#              STD-YM      BF_1M     BF_12M
# Date
# 2006-05-31  2006-05        NaN        NaN
# 2007-06-29  2007-06  36.162109  35.633759

# %%
# 거래 내역 추가
# 구매 조건 --> ((전월 종가/전 년도 종가)-1) 값이 0보다 크고 무한대가 아닌 경우

df['trade']=''
for i in month_list_df.index:
    signal=''

    # 절대 모멘텀 계산
    monentum_index= (month_list_df.loc[i,"BF_1M"]/ month_list_df.loc[i,"BF_12M"]) - 1
    
    # 절대 모멭넘 지표에 따라서 True / Fasle 로 구분
    flag = True if((monentum_index >0 ) and (monentum_index!=np.inf) and (monentum_index !=-np.inf)) else False

    if flag:
        signal ='buy'
    print('날짜:',i, "모멘텀 인덱스 :", monentum_index, 'flag :',flag, 'signal :', signal)

    df.loc[i,'trade']=signal
# Out:
# 날짜: 2006-05-31 00:00:00 모멘텀 인덱스 : nan flag : False signal :
# 날짜: 2006-06-30 00:00:00 모멘텀 인덱스 : nan flag : False signal :
# 날짜: 2006-07-31 00:00:00 모멘텀 인덱스 : nan flag : False signal :
# 날짜: 2006-08-31 00:00:00 모멘텀 인덱스 : nan flag : False signal :
# 날짜: 2006-09-29 00:00:00 모멘텀 인덱스 : nan flag : False signal :
# 날짜: 2006-10-31 00:00:00 모멘텀 인덱스 : nan flag : False signal :
# 날짜: 2006-11-30 00:00:00 모멘텀 인덱스 : nan flag : False signal :
# 날짜: 2006-12-29 00:00:00 모멘텀 인덱스 : nan flag : False signal :
# 날짜: 2007-01-31 00:00:00 모멘텀 인덱스 : nan flag : False signal :
# 날짜: 2007-02-28 00:00:00 모멘텀 인덱스 : nan flag : False signal :
# 날짜: 2007-03-30 00:00:00 모멘텀 인덱스 : nan flag : False signal :
# 날짜: 2007-04-30 00:00:00 모멘텀 인덱스 : nan flag : False signal :
# 날짜: 2007-05-31 00:00:00 모멘텀 인덱스 : 0.02123525695897932 flag : True signal : buy
# 날짜: 2007-06-29 00:00:00 모멘텀 인덱스 : 0.014827231670955676 flag : True signal : buy
# 날짜: 2007-07-31 00:00:00 모멘텀 인덱스 : -0.019604388455949806 flag : False signal :
# ...

# %%
df['trade'].value_counts()
# Out:
#        3234
# buy      61
# Name: trade, dtype: int64

# %% [markdown]
# ### 수익율 계산
# 1. 파생변수(return) 값은 1로 생성
# 2. rtn =1.0 ,sell변수는 0으로 생성
# 3. 반복문을 이용해서 현재의 trade가 buy고 전 행의 trade가 ''인 경우 구매 날
# 4. 전 행의  trade가 buy이고 현재의 trade가 ''인 경우 판매 날
# 5. 수익율 계산하여 return에 대입
#
# ### 누적 수익율 계산
# 1. acc_rtn=1.0 생성
# 2. return의 항목들을 누적 곱하여 acc_rtn컬럼에 대입
# 3. 최종적으로 acc_rtn을 출력

# %%
df['return']=1.0

rtn=1.0
buy=0.0
sell=0

# index의 데이터 값이 unique해서 
for i in df.index:         
    # 구매한 날을 체크, 구매가 지정
    if (df.loc[i,"trade"] == "buy") and (df.shift(1).loc[i,"trade"]== ""):
        buy=df.loc[i,"Adj Close"]
        # print (buy)
        # 이 시점에 사고 그 값을 변수 buy 값에 저장해놓는다
        # print("구매일:",i ,'구매가격',buy)

    # 판매한 날을 체크, 판매가 지정, 수익률 계산
    elif (df.shift(1).loc[i,"trade"]=="buy") and (df.loc[i,"trade"]==""):
        sell= df.loc[i,"Adj Close"]
        rtn= (sell-buy)/buy +1
        df.loc[i,'return']=rtn
        # print("판매일:",i ,'판매가격',sell)

        # 이 시점에 팔거야 근데 산 시점은 위의 if문일때 샀음--> 수익률을 팔 시점의 판 값(이 건 위 for문에 저장되어 있음), 산 시점의 산 값을 변수에 저장해놓는다
        # 그렇게 나온 값을 rtn에 저장해놓고, 판 시점의 df['rtn']에 대입한다
        # 다시 사는 것부터 반복

acc_rtn=1.0

for i in df.index:
    acc_rtn *= df.loc[i,'return']
    df.loc[i,'acc_rtn']= acc_rtn
    
print('누적 수익율:',acc_rtn)
# Out:
# 누적 수익율: 1.165001849964831

# %%
# 누적곱률 해주는 함수
df["return"].cumprod()
# Out:
# Date
# 2006-05-22    1.000000
# 2006-05-23    1.000000
# 2006-05-24    1.000000
# 2006-05-25    1.000000
# 2006-05-26    1.000000
#                 ...
# 2019-06-18    1.165002
# 2019-06-19    1.165002
# 2019-06-20    1.165002
# 2019-06-21    1.165002
# 2019-06-24    1.165002
# Name: return, Length: 3295, dtype: float64

# %% [markdown]
# # 절대 모멘텀을 함수화
# 1. 첫 번째 함수
#     - 매개변수 1개(데이터 프레임)
#     - 데이터프레임에 결측치와 이상치를 제거
#     - 수정종가를 제외한 나머지 컬럼은 삭제
#     - 인덱스를 시계열로 변경하기
#     - "STD-YM" 파생변수를 생성하여 인덱스의 년-월 추출해서 대입
# 2. 두 번째 함수
#     - 매개변수 1개(데이터 프레임)
#     - 새로운 데이터프레임(df2) 생성
#     - 인자값으로 받아온 데이터프레임에서 년-월별 마지막 데이터들을 새로운 데이터프레임에 대입
#     - df2에 파생변수 2개 생성
#         - 'BF_1M': 전월의 종가, 결측치는 0으로 대입
#         - "BF_12M": 전 년도의 종가, 결측치는 0으로 대입
#         - return df2
# 3. 세 번째 함수
#     - 매개변수 2개(첫번째 함수의 결과(df1), 두번째 함수의 결과(df2))
#     - df1에 trade 컬럼을 생성, 값은 ''
#     - df1에 return 칼럼을 생성, 값은 1
#     - df2의 값들을 이용하여 momnentum_index를 구하고 df1에 거래 내역 삽입
#     - df1의 거래 내역을 이용하여 수익율 return 컬럼에 대입
#     - return 컬럼의 데이터를 가지고 누적수익율(acc_rtn)에 대입
#     - 누적 수익율을 print를 이용하여 출력
#     - df1을 리턴

# %% [markdown]
# #### 함수화 코드

# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %%
df=pd.read_csv("../csv/GDX.csv",index_col='Date')
df
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2006-05-22  36.520000  37.290001  35.869999  37.230000  34.280224     197100
# 2006-05-23  37.750000  39.220001  37.750000  37.959999  34.952393     620900
# 2006-05-24  37.130001  37.570000  35.869999  36.520000  33.626480     638600
# 2006-05-25  37.180000  38.320000  36.980000  38.320000  35.283867     367000
# 2006-05-26  38.740002  38.740002  37.770000  38.549999  35.495640     269400
# ...               ...        ...        ...        ...        ...        ...
# 2019-06-18  23.750000  23.879999  23.350000  23.670000  23.670000   44411200
# 2019-06-19  23.520000  24.030001  23.450001  24.000000  24.000000   46273800
# 2019-06-20  24.660000  25.170000  24.540001  25.049999  25.049999  131981000
# 2019-06-21  25.000000  25.240000  24.680000  25.209999  25.209999   50304400
# 2019-06-24  25.309999  25.770000  25.260000  25.703501  25.703501   27806170
#
# [3295 rows x 6 columns]

# %%
def momentum1(df,col):
    
    # 만약에 인덱스가 Date가 아니면? Date컬럼을 인덱스로 변경
    if 'Date' in df.columns:
        df=df.set_index("Date")

    # 결측치와 이상치를 제거
    df=df.loc[~df.isin([np.nan,np.inf,-np.inf]).any(axis=1)]
    # 수정종가를 제외한 나머지 컬럼 삭제
    df=df[[col]]
    # 인덱스를 시계열로 변경
    df.index=pd.to_datetime(df.index,format="%Y-%m-%d")
    # 'STD-YM'컬럼을 생성
    df['STD-YM']=list(map(lambda x: datetime.strftime(x,'%Y-%m'),df.index))

    return df

# %%
# 첫번째 함수 실행해보기
momentum1(df,'Adj Close')
# Out:
#             Adj Close   STD-YM
# Date
# 2006-05-22  34.280224  2006-05
# 2006-05-23  34.952393  2006-05
# 2006-05-24  33.626480  2006-05
# 2006-05-25  35.283867  2006-05
# 2006-05-26  35.495640  2006-05
# ...               ...      ...
# 2019-06-18  23.670000  2019-06
# 2019-06-19  24.000000  2019-06
# 2019-06-20  25.049999  2019-06
# 2019-06-21  25.209999  2019-06
# 2019-06-24  25.703501  2019-06
#
# [3295 rows x 2 columns]

# %%
def momentum2(df):

    df2= pd.DataFrame()
    # 리스트값을 만들어서 for문을 돌림
    _list=df["STD-YM"].unique()
    col=df.columns[0]

    

    for i in _list:
        last_df=df.loc[df["STD-YM"] ==i].tail(1)
        df2 =pd.concat([df2, last_df])

    df2['BF_1M']=df2.shift(1)[col].fillna(0)
    df2['BF_12M']=df2.shift(12)[col].fillna(0)
    
    return df2

# %%
def momentum3(df1,df2):

    col=df1.columns[0]
    df1['trade']=''
    
    for i in df2.index:
        signal=''

        # 절대 모멘텀 계산
        monentum_index= (df2.loc[i,"BF_1M"]/ df2.loc[i,"BF_12M"]) - 1
        
        # 절대 모멭넘 지표에 따라서 True / Fasle 로 구분
        flag = True if((monentum_index >0 ) and (monentum_index!=np.inf) and (monentum_index !=-np.inf)) else False

        if flag:
            signal ='buy'
        #print('날짜:',i, "모멘텀 인덱스 :", monentum_index, 'flag :',flag, 'signal :', signal)

        df1.loc[i,'trade']=signal

        df1['return']=1.0

    rtn=1.0
    buy=0.0
    sell=0

    # index의 데이터 값이 unique해서 
    for i in df1.index:         
        # 구매한 날을 체크, 구매가 지정
        if (df1.loc[i,"trade"] == "buy") and (df1.shift(1).loc[i,"trade"]== ""):
            buy=df1.loc[i,col]
            # print (buy)
            # 이 시점에 사고 그 값을 변수 buy 값에 저장해놓는다
            # print("구매일:",i ,'구매가격',buy)

        # 판매한 날을 체크, 판매가 지정, 수익률 계산
        elif (df1.shift(1).loc[i,"trade"]=="buy") and (df1.loc[i,"trade"]==""):
            sell= df1.loc[i,col]
            rtn= (sell-buy)/buy +1
            df1.loc[i,'return']=rtn
    acc_rtn=1.0

    for i in df1.index:

        acc_rtn *= df1.loc[i,'return']
        df1.loc[i,'acc_rtn']= acc_rtn
        
    print('누적 수익율:',acc_rtn)
    return df1

# %%
df=momentum1(df,'Adj Close')
df2=momentum2(df)
momentum3(df,df2)
# Out:
# C:\Users\dgh06\AppData\Local\Temp\ipykernel_24156\1401882277.py:10: RuntimeWarning: invalid value encountered in scalar divide
#   monentum_index= (df2.loc[i,"BF_1M"]/ df2.loc[i,"BF_12M"]) - 1
# C:\Users\dgh06\AppData\Local\Temp\ipykernel_24156\1401882277.py:10: RuntimeWarning: divide by zero encountered in scalar divide
#   monentum_index= (df2.loc[i,"BF_1M"]/ df2.loc[i,"BF_12M"]) - 1
# 누적 수익율: 1.165001849964831
#             Adj Close   STD-YM trade  return   acc_rtn
# Date
# 2006-05-22  34.280224  2006-05           1.0  1.000000
# 2006-05-23  34.952393  2006-05           1.0  1.000000
# 2006-05-24  33.626480  2006-05           1.0  1.000000
# 2006-05-25  35.283867  2006-05           1.0  1.000000
# 2006-05-26  35.495640  2006-05           1.0  1.000000
# ...               ...      ...   ...     ...       ...
# 2019-06-18  23.670000  2019-06           1.0  1.165002
# 2019-06-19  24.000000  2019-06           1.0  1.165002
# 2019-06-20  25.049999  2019-06           1.0  1.165002
# ...
